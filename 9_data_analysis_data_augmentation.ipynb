# %%
import numpy as np
import pandas as pd

"""
Visualize and analyze data.
    
@author: Juan Felipe Latorre Gil - jflatorreg@unal.edu.co
"""

# %%
path_LR  = './data_augmentation/results/df_LR.csv'
path_SVC = './data_augmentation/results/df_SVC.csv'
path_RF  = './data_augmentation/results/df_RF.csv'

# %%
df_LR = pd.read_csv(path_LR, index_col= 'Unnamed: 0')
df_SVC = pd.read_csv(path_SVC, index_col= 'Unnamed: 0')
df_RF = pd.read_csv(path_RF, index_col= 'Unnamed: 0')

# %%
df_LR.head()
# Out:
#    Sample Number  Precision Micro  Precision Macro  Precision Weighted  \
# 0          590.0         0.768769         0.768769            0.768769
# 1          605.0         0.798799         0.798799            0.798799
# 2          620.0         0.804805         0.804805            0.804805
# 3          635.0         0.816817         0.816817            0.816817
# 4          650.0         0.840841         0.840841            0.840841
#
#    Recall Micro  Recall Macro  Recall Weighted  F1 Micro  F1 Macro  \
# 0      0.858108      0.658452         0.667143  0.820510  0.768769
# 1      0.873977      0.703095         0.723233  0.839691  0.798799
# 2      0.877120      0.712023         0.733780  0.843578  0.804805
# 3      0.883423      0.729880         0.754273  0.851440  0.816817
# 4      0.889683      0.767797         0.794600  0.863964  0.840841
#
#    F1 Weighted Resolution
# 0     0.727345        Low
# 1     0.770570        Low
# 2     0.778790        Low
# ...

# %%
df_SVC.head()
# Out:
#    Sample Number  Precision Micro  Precision Macro  Precision Weighted  \
# 0          590.0         0.933934         0.933934            0.933934
# 1          605.0         0.936937         0.936937            0.936937
# 2          620.0         0.936937         0.936937            0.936937
# 3          635.0         0.936937         0.936937            0.936937
# 4          650.0         0.939940         0.939940            0.939940
#
#    Recall Micro  Recall Macro  Recall Weighted  F1 Micro  F1 Macro  \
# 0      0.950997      0.903988         0.922269  0.938515  0.933934
# 1      0.952957      0.908452         0.926004  0.941078  0.936937
# 2      0.952957      0.908452         0.926004  0.941078  0.936937
# 3      0.952957      0.908452         0.926004  0.941078  0.936937
# 4      0.951609      0.915118         0.930089  0.942588  0.939940
#
#    F1 Weighted Resolution
# 0     0.932125        Low
# 1     0.935314        Low
# 2     0.935314        Low
# ...

# %%
df_RF.head()
# Out:
#    Sample Number  Precision Micro  Precision Macro  Precision Weighted  \
# 0          590.0         0.849850         0.849850            0.849850
# 1          605.0         0.903904         0.903904            0.903904
# 2          620.0         0.906907         0.906907            0.906907
# 3          635.0         0.912913         0.912913            0.912913
# 4          650.0         0.885886         0.885886            0.885886
#
#    Recall Micro  Recall Macro  Recall Weighted  F1 Micro  F1 Macro  \
# 0      0.907749      0.776786         0.805509  0.877553  0.849850
# 1      0.936759      0.857143         0.882911  0.916058  0.903904
# 2      0.938492      0.861607         0.886920  0.918359  0.906907
# 3      0.942000      0.870536         0.894855  0.923015  0.912913
# 4      0.926641      0.830357         0.858266  0.902628  0.885886
#
#    F1 Weighted Resolution
# 0     0.835906        Low
# 1     0.899140        Low
# 2     0.902481        Low
# ...

# %% [markdown]
# # Gráfica

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use(['ggplot','seaborn-paper'])

# %%
size = (8, 7)
a4_dims = size
palette_3 = sns.color_palette("mako_r",3)

# %% [markdown]
# # LR

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.lineplot(x="Sample Number", y="F1 Micro", legend="full", hue="Resolution", palette=palette_3,
                  data=df_LR)
#sns.scatterplot
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#ax.set_xlim(-2.5,3.5)
#plt.savefig('./results/graphics/ST_LR.pdf', format='pdf', bbox_inches='tight')
plt.axvline(590, 0, 1, linestyle='--', color='black')
plt.axvline(590*2, 0, 1, linestyle='--', color='black')
plt.axvline(590*3, 0, 1, linestyle='--', color='black')
plt.axvline(590*4, 0, 1, linestyle='--', color='black')
plt.ylabel('$F_1$ Score')
plt.xlabel('Training Sample Size')
plt.savefig('./results/graphics/DA_LR.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.lineplot(x="Sample Number", y="Precision Micro", legend="full", hue="Resolution", palette=palette_3,
                  data=df_LR)
#sns.scatterplot
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#ax.set_xlim(-2.5,3.5)
#plt.savefig('./results/graphics/ST_LR.pdf', format='pdf', bbox_inches='tight')
plt.axvline(590, 0, 1, linestyle='--', color='black')
plt.axvline(590*2, 0, 1, linestyle='--', color='black')
plt.axvline(590*3, 0, 1, linestyle='--', color='black')
plt.axvline(590*4, 0, 1, linestyle='--', color='black')
plt.show()

# %% [markdown]
# # SVC

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.lineplot(x="Sample Number", y="F1 Micro", legend="full", hue="Resolution", palette=palette_3,
                  data=df_SVC)
#sns.scatterplot
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#ax.set_xlim(-2.5,3.5)
#plt.savefig('./results/graphics/ST_LR.pdf', format='pdf', bbox_inches='tight')
plt.axvline(590, 0, 1, linestyle='--', color='black')
plt.axvline(590*2, 0, 1, linestyle='--', color='black')
plt.axvline(590*3, 0, 1, linestyle='--', color='black')
plt.axvline(590*4, 0, 1, linestyle='--', color='black')
plt.ylabel('$F_1$ Score')
plt.xlabel('Training Sample Size')
plt.savefig('./results/graphics/DA_SVC.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # RF

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.lineplot(x="Sample Number", y="F1 Micro", legend="full", hue="Resolution", palette=palette_3,
                  data=df_RF)
#sns.scatterplot
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#ax.set_xlim(-2.5,3.5)
#plt.savefig('./results/graphics/ST_LR.pdf', format='pdf', bbox_inches='tight')
plt.axvline(590, 0, 1, linestyle='--', color='black')
plt.axvline(590*2, 0, 1, linestyle='--', color='black')
plt.axvline(590*3, 0, 1, linestyle='--', color='black')
plt.axvline(590*4, 0, 1, linestyle='--', color='black')
plt.ylabel('$F_1$ Score')
plt.xlabel('Training Sample Size')
plt.savefig('./results/graphics/DA_RF.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.lineplot(x="Sample Number", y="F1 Macro", legend="full", hue="Resolution", palette=palette_3,
                  data=df_RF)
#sns.scatterplot
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#ax.set_xlim(-2.5,3.5)
#plt.savefig('./results/graphics/ST_LR.pdf', format='pdf', bbox_inches='tight')
plt.axvline(590, 0, 1, linestyle='--', color='black')
plt.axvline(590*2, 0, 1, linestyle='--', color='black')
plt.axvline(590*3, 0, 1, linestyle='--', color='black')
plt.axvline(590*4, 0, 1, linestyle='--', color='black')
plt.show()
